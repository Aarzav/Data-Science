# %%
import pandas as pd
import numpy as np

# %%
# series :Always 1D and always contain index

# %%
s1=pd.Series([1,2,3,4])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1.values
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
s2=pd.Series([1,2.0,3,4.0])
s2
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# dtype: float64

# %%
#operation on series

# %%
s2.sum()
# Out:
# 10.0

# %%
s2.max()
# Out:
# 4.0

# %%
s2.min()
# Out:
# 1.0

# %%
s2.argmax()## shows index of maximum value
# Out:
# 3

# %%
s2.argmin()
# Out:
# 0

# %%
s2.cumsum()# cummulative sum
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3    10.0
# dtype: float64

# %%
s2.cumprod()
# Out:
# 0     1.0
# 1     2.0
# 2     6.0
# 3    24.0
# dtype: float64

# %%
s2.pct_change()#pct_change = (current-previous)/previous #NaN not a number
# Out:
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.333333
# dtype: float64

# %%
# Indexing a Series

# %%
s2[1]
# Out:
# 2.0

# %%
s2[0]
# Out:
# 1.0

# %%
s2[2:]# from 2 to all
# Out:
# 2    3.0
# 3    4.0
# dtype: float64

# %%
s2[:-1]# from 0 to last
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# dtype: float64

# %%
s2[::-1]# reverse
# Out:
# 3    4.0
# 2    3.0
# 1    2.0
# 0    1.0
# dtype: float64

# %%
s2[-3:]
# Out:
# 1    2.0
# 2    3.0
# 3    4.0
# dtype: float64

# %%
s2.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s2[1]=100
s2
# Out:
# 0      1.0
# 1    100.0
# 2      3.0
# 3      4.0
# dtype: float64

# %%
# DAtaframe : similar to table in SQL with rows and columns

# %%
student=['john','raj','rick','riya','priya']
age=[30,25,28,18,12]

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['Name']=student
df['Age']=age

# %%
df
# Out:
#     Name  Age
# 0   john   30
# 1    raj   25
# 2   rick   28
# 3   riya   18
# 4  priya   12

# %%
#other ways to create dataframe

# %%
df=pd.DataFrame(zip(student,age),columns=['Name','Age'])#combine the table and store in dataframe
df
# Out:
#     Name  Age
# 0   john   30
# 1    raj   25
# 2   rick   28
# 3   riya   18
# 4  priya   12

# %%
pd.DataFrame({'A':[1,2,3],
             'B':['A','B','C']})
# Out:
#    A  B
# 0  1  A
# 1  2  B
# 2  3  C

# %%
pd.DataFrame({'A':student,
             'B':age})
# Out:
#        A   B
# 0   john  30
# 1    raj  25
# 2   rick  28
# 3   riya  18
# 4  priya  12

# %%
# Indexing Dataframe

# %%
# LOC => works on column and row names

# %%
df
# Out:
#     Name  Age
# 0   john   30
# 1    raj   25
# 2   rick   28
# 3   riya   18
# 4  priya   12

# %%
df.loc[:,:]# display everything
# Out:
#     Name  Age
# 0   john   30
# 1    raj   25
# 2   rick   28
# 3   riya   18
# 4  priya   12

# %%
df.loc[1:3,:]# display row no. 1,2,3 and all columns
# Out:
#    Name  Age
# 1   raj   25
# 2  rick   28
# 3  riya   18

# %%
df.loc[[0,2,4],:]
# Out:
#     Name  Age
# 0   john   30
# 2   rick   28
# 4  priya   12

# %%
df.loc[:,['Age']]
# Out:
#    Age
# 0   30
# 1   25
# 2   28
# 3   18
# 4   12

# %%
df.loc[[1,2,4],['Age']]
# Out:
#    Age
# 1   25
# 2   28
# 4   12

# %%
df.loc[[1,2,4],['Age','Name']]
# Out:
#    Age   Name
# 1   25    raj
# 2   28   rick
# 4   12  priya

# %%
# Changing Index

# %%
df2=df.copy(deep=True)
#Deep = True will create a seperate detached copy of df in df2 and df will remain same
df2
# Out:
#     Name  Age
# 0   john   30
# 1    raj   25
# 2   rick   28
# 3   riya   18
# 4  priya   12

# %%
df2.set_index('Age',inplace=True)# Inplace operator changes the original df2
# set index will set name as the index of the Dataframe

# %%
df2
# Out:
#       Name
# Age
# 30    john
# 25     raj
# 28    rick
# 18    riya
# 12   priya

# %%
df2.loc[[25,28],:]
# Out:
#      Name
# Age
# 25    raj
# 28   rick

# %%
# iloc =>index location

# %%
df.iloc[[1,4],:]
# Out:
#     Name  Age
# 1    raj   25
# 4  priya   12

# %%
df.iloc[1:3,:]# iloc consider row position same as python index
# Out:
#    Name  Age
# 1   raj   25
# 2  rick   28

# %%
df.iloc[:,1:]
# Out:
#    Age
# 0   30
# 1   25
# 2   28
# 3   18
# 4   12

# %%
# Reading Files using Pandas
# Different type of file format
# CSV : Comma Seperated Values
# Xlsx : Excel
# HTML : html tables

# %%
df=pd.read_csv(r"C:\Users\aarza\Desktop\python\Basics\Pandas\CAR DETAILS FROM CAR DEKHO.csv")
# r(raw string) is used to treat the path string so thatit consider \ as path

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.head()# default starting 5 observation
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.head(7)
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 0              Maruti 800 AC  2007          60000      70000  Petrol
# 1   Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2       Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3     Datsun RediGO T Option  2017         250000      46000  Petrol
# 4      Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5       Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6  Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner
# 5  Individual       Manual   First Owner
# 6  Individual       Manual   First Owner

# %%
df.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
## checking columns
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
# showing dtypes of all columns
df.dtypes
# Out:
# name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# dtype: object

# %%
df.info()# show info of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
# Describe Dataframe => USe numerical column to show summary statistics
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
## finding stats for individual columns

# %%
df.year.max()#give maximum value for Year column
# Out:
# 2020

# %%
df['year'].min()#give minimum value for Year column
# Out:
# 1992

# %%
df['selling_price'].min()
# Out:
# 20000

# %%
df['selling_price'].max()
# Out:
# 8900000

# %%
#creating new columns

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
#creating new column
df['selling_price_in_lakhs']=df['selling_price']/100000

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner  selling_price_in_lakhs
# 0  Individual       Manual   First Owner                    0.60
# 1  Individual       Manual   First Owner                    1.35
# 2  Individual       Manual   First Owner                    6.00
# 3  Individual       Manual   First Owner                    2.50
# 4  Individual       Manual  Second Owner                    4.50

# %%
#finding unique in columns

# %%
df['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
df['name'].unique()#actual unique
# Out:
# array(['Maruti 800 AC', 'Maruti Wagon R LXI Minor',
#        'Hyundai Verna 1.6 SX', ..., 'Mahindra Verito 1.5 D6 BSIII',
#        'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV',
#        'Hyundai i20 Magna 1.4 CRDi'], dtype=object)

# %%
df['name'].nunique()# number of unique
# Out:
# 1491

# %%
df['fuel'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
df['fuel'].nunique()
# Out:
# 5

# %%
#starting function

# %%
#Ascending order
df.sort_values('selling_price')
# Out:
#                                                    name  year  selling_price  \
# 2662                              Ford Ikon 1.6 ZXI NXt  2005          20000
# 2495                                  Ford Ikon 1.4 ZXi  2000          22000
# 2444                                      Maruti 800 EX  2004          30000
# 3206                                   OpelCorsa 1.4 GL  2002          35000
# 2849                                 Tata Nano Std BSII  2009          35000
# ...                                                 ...   ...            ...
# 1023                            BMW X5 xDrive 30d xLine  2019        4950000
# 2239                            BMW X5 xDrive 30d xLine  2019        4950000
# 3969            Mercedes-Benz GLS 2016-2020 350d 4MATIC  2016        5500000
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 3872           Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
# ...

# %%
#decsending function
df.sort_values('selling_price',ascending=False)
# Out:
#                                                    name  year  selling_price  \
# 3872           Audi RS7 2015-2019 Sportback Performance  2016        8900000
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 3969            Mercedes-Benz GLS 2016-2020 350d 4MATIC  2016        5500000
# 2258                            BMW X5 xDrive 30d xLine  2019        4950000
# 612                             BMW X5 xDrive 30d xLine  2019        4950000
# ...                                                 ...   ...            ...
# 2849                                 Tata Nano Std BSII  2009          35000
# 1832                                    Tata Nano LX SE  2012          35000
# 2444                                      Maruti 800 EX  2004          30000
# 2495                                  Ford Ikon 1.4 ZXi  2000          22000
# 2662                              Ford Ikon 1.6 ZXI NXt  2005          20000
#
# ...

# %%
#sorting mutliple columns
df.sort_values(['year','selling_price'])
# Out:
#                                            name  year  selling_price  \
# 3334                         Maruti 800 AC BSII  1992          50000
# 631                    Maruti Gypsy E MG410W ST  1995          95000
# 2972                       Mahindra Jeep MM 540  1996         200000
# 61                     Mahindra Jeep CL 500 MDI  1996         250000
# 3661                             Maruti 800 Std  1997          50000
# ...                                         ...   ...            ...
# 1780       Ford Ecosport Thunder Edition Diesel  2020        1331000
# 1778  Ford EcoSport 1.5 TDCi Titanium Plus BSIV  2020        1334000
# 289              Mahindra XUV500 W11 Option AWD  2020        1400000
# 1516             Mahindra XUV500 W11 Option AWD  2020        1400000
# 963                           Audi A5 Sportback  2020        4700000
#
#       km_driven    fuel seller_type transmission                 owner  \
# ...

# %%
df.sort_values(['year','selling_price'],ascending=False)
# Out:
#                                            name  year  selling_price  \
# 963                           Audi A5 Sportback  2020        4700000
# 289              Mahindra XUV500 W11 Option AWD  2020        1400000
# 1516             Mahindra XUV500 W11 Option AWD  2020        1400000
# 1778  Ford EcoSport 1.5 TDCi Titanium Plus BSIV  2020        1334000
# 1780       Ford Ecosport Thunder Edition Diesel  2020        1331000
# ...                                         ...   ...            ...
# 3661                             Maruti 800 Std  1997          50000
# 61                     Mahindra Jeep CL 500 MDI  1996         250000
# 2972                       Mahindra Jeep MM 540  1996         200000
# 631                    Maruti Gypsy E MG410W ST  1995          95000
# 3334                         Maruti 800 AC BSII  1992          50000
#
#       km_driven    fuel seller_type transmission                 owner  \
# ...

# %%
df.sort_index()#sort ascending index
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner  selling_price_in_lakhs
# ...

# %%
df.sort_index(ascending=False)
# Out:
#                                      name  year  selling_price  km_driven  \
# 4339                     Renault KWID RXT  2016         225000      40000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# ...                                   ...   ...            ...        ...
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 0                           Maruti 800 AC  2007          60000      70000
#
#         fuel seller_type transmission         owner  selling_price_in_lakhs
# ...

# %%
#setting index
df=df.set_index('year')#assigning new index to dataframe

# %%
df.head()
# Out:
#                           name  selling_price  km_driven    fuel seller_type  \
# year
# 2007             Maruti 800 AC          60000      70000  Petrol  Individual
# 2007  Maruti Wagon R LXI Minor         135000      50000  Petrol  Individual
# 2012      Hyundai Verna 1.6 SX         600000     100000  Diesel  Individual
# 2017    Datsun RediGO T Option         250000      46000  Petrol  Individual
# 2014     Honda Amaze VX i-DTEC         450000     141000  Diesel  Individual
#
#      transmission         owner  selling_price_in_lakhs
# year
# 2007       Manual   First Owner                    0.60
# 2007       Manual   First Owner                    1.35
# 2012       Manual   First Owner                    6.00
# 2017       Manual   First Owner                    2.50
# 2014       Manual  Second Owner                    4.50

# %%
df.sort_index(ascending=True)
# Out:
#                                     name  selling_price  km_driven    fuel  \
# year
# 1992                  Maruti 800 AC BSII          50000     100000  Petrol
# 1995            Maruti Gypsy E MG410W ST          95000     100000  Petrol
# 1996                Mahindra Jeep MM 540         200000      60000  Diesel
# 1996            Mahindra Jeep CL 500 MDI         250000      35000  Diesel
# 1997            Mahindra Jeep CL 500 MDI         150000     120000  Diesel
# ...                                  ...            ...        ...     ...
# 2020               Maruti Ertiga 1.5 VDI         550000      90000  Diesel
# 2020    Hyundai Grand i10 Nios AMT Magna         640000       4000  Petrol
# 2020           Ford Aspire Titanium BSIV         828999       1010  Petrol
# 2020             Maruti Alto K10 LXI CNG         282000      40000     CNG
# 2020  Ford Figo Aspire 1.5 TDCi Titanium         530000      45000  Diesel
#
# ...

# %%
#reset index
df=df.reset_index(drop=False)

# %%
df.head()
# Out:
#    year                      name  selling_price  km_driven    fuel  \
# 0  2007             Maruti 800 AC          60000      70000  Petrol
# 1  2007  Maruti Wagon R LXI Minor         135000      50000  Petrol
# 2  2012      Hyundai Verna 1.6 SX         600000     100000  Diesel
# 3  2017    Datsun RediGO T Option         250000      46000  Petrol
# 4  2014     Honda Amaze VX i-DTEC         450000     141000  Diesel
#
#   seller_type transmission         owner  selling_price_in_lakhs
# 0  Individual       Manual   First Owner                    0.60
# 1  Individual       Manual   First Owner                    1.35
# 2  Individual       Manual   First Owner                    6.00
# 3  Individual       Manual   First Owner                    2.50
# 4  Individual       Manual  Second Owner                    4.50

# %%
df2=df.set_index('year')#assigning new index to dataframe
df2.head()
# Out:
#                           name  selling_price  km_driven    fuel seller_type  \
# year
# 2007             Maruti 800 AC          60000      70000  Petrol  Individual
# 2007  Maruti Wagon R LXI Minor         135000      50000  Petrol  Individual
# 2012      Hyundai Verna 1.6 SX         600000     100000  Diesel  Individual
# 2017    Datsun RediGO T Option         250000      46000  Petrol  Individual
# 2014     Honda Amaze VX i-DTEC         450000     141000  Diesel  Individual
#
#      transmission         owner  selling_price_in_lakhs
# year
# 2007       Manual   First Owner                    0.60
# 2007       Manual   First Owner                    1.35
# 2012       Manual   First Owner                    6.00
# 2017       Manual   First Owner                    2.50
# 2014       Manual  Second Owner                    4.50

# %%
df2=df2.reset_index(drop=True)

# %%
df2.head()
# Out:
#                        name  selling_price  km_driven    fuel seller_type  \
# 0             Maruti 800 AC          60000      70000  Petrol  Individual
# 1  Maruti Wagon R LXI Minor         135000      50000  Petrol  Individual
# 2      Hyundai Verna 1.6 SX         600000     100000  Diesel  Individual
# 3    Datsun RediGO T Option         250000      46000  Petrol  Individual
# 4     Honda Amaze VX i-DTEC         450000     141000  Diesel  Individual
#
#   transmission         owner  selling_price_in_lakhs
# 0       Manual   First Owner                    0.60
# 1       Manual   First Owner                    1.35
# 2       Manual   First Owner                    6.00
# 3       Manual   First Owner                    2.50
# 4       Manual  Second Owner                    4.50

# %%
#not assigned it back to original dataframe so original dataframe remain same
df.set_index('name').set_index('seller_type')
# Out:
#              year  selling_price  km_driven    fuel transmission  \
# seller_type
# Individual   2007          60000      70000  Petrol       Manual
# Individual   2007         135000      50000  Petrol       Manual
# Individual   2012         600000     100000  Diesel       Manual
# Individual   2017         250000      46000  Petrol       Manual
# Individual   2014         450000     141000  Diesel       Manual
# ...           ...            ...        ...     ...          ...
# Individual   2014         409999      80000  Diesel       Manual
# Individual   2014         409999      80000  Diesel       Manual
# Individual   2009         110000      83000  Petrol       Manual
# Individual   2016         865000      90000  Diesel       Manual
# Individual   2016         225000      40000  Petrol       Manual
#
#                     owner  selling_price_in_lakhs
# seller_type
# Individual    First Owner                 0.60000
# Individual    First Owner                 1.35000
# ...

# %%
df.head()
# Out:
#    year                      name  selling_price  km_driven    fuel  \
# 0  2007             Maruti 800 AC          60000      70000  Petrol
# 1  2007  Maruti Wagon R LXI Minor         135000      50000  Petrol
# 2  2012      Hyundai Verna 1.6 SX         600000     100000  Diesel
# 3  2017    Datsun RediGO T Option         250000      46000  Petrol
# 4  2014     Honda Amaze VX i-DTEC         450000     141000  Diesel
#
#   seller_type transmission         owner  selling_price_in_lakhs
# 0  Individual       Manual   First Owner                    0.60
# 1  Individual       Manual   First Owner                    1.35
# 2  Individual       Manual   First Owner                    6.00
# 3  Individual       Manual   First Owner                    2.50
# 4  Individual       Manual  Second Owner                    4.50

# %%
df.set_index('name').set_index('seller_type').reset_index(drop=False)
# Out:
#      seller_type  year  selling_price  km_driven    fuel transmission  \
# 0     Individual  2007          60000      70000  Petrol       Manual
# 1     Individual  2007         135000      50000  Petrol       Manual
# 2     Individual  2012         600000     100000  Diesel       Manual
# 3     Individual  2017         250000      46000  Petrol       Manual
# 4     Individual  2014         450000     141000  Diesel       Manual
# ...          ...   ...            ...        ...     ...          ...
# 4335  Individual  2014         409999      80000  Diesel       Manual
# 4336  Individual  2014         409999      80000  Diesel       Manual
# 4337  Individual  2009         110000      83000  Petrol       Manual
# 4338  Individual  2016         865000      90000  Diesel       Manual
# 4339  Individual  2016         225000      40000  Petrol       Manual
#
#              owner  selling_price_in_lakhs
# 0      First Owner                 0.60000
# ...

# %%
df.columns
# Out:
# Index(['year', 'name', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'selling_price_in_lakhs'],
#       dtype='object')

# %%
##chaning position of column adding and deleting columns

# %%
df=df.loc[:,['name', 'selling_price','year','km_driven', 'fuel', 'seller_type',
       'transmission', 'owner']]

# %%
df.head(2)
# Out:
#                        name  selling_price  year  km_driven    fuel  \
# 0             Maruti 800 AC          60000  2007      70000  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000  Petrol
#
#   seller_type transmission        owner
# 0  Individual       Manual  First Owner
# 1  Individual       Manual  First Owner

# %%
df.insert(loc=4,column='year2',value=df.year)#if same name columns require use allow_duplicates=True
#insert after 4 position

# %%
df.head()
# Out:
#                        name  selling_price  year  km_driven  year2    fuel  \
# 0             Maruti 800 AC          60000  2007      70000   2007  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000   2007  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000   2012  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000   2017  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000   2014  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.drop('year',axis=1).head(1)#deleting column
# Out:
#             name  selling_price  km_driven  year2    fuel seller_type  \
# 0  Maruti 800 AC          60000      70000   2007  Petrol  Individual
#
#   transmission        owner
# 0       Manual  First Owner

# %%
# some more operations on columns

# %%
df['static_column_value']=1 #single value throughout the dataframe
df.head()
# Out:
#                        name  selling_price  year  km_driven  year2    fuel  \
# 0             Maruti 800 AC          60000  2007      70000   2007  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000   2007  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000   2012  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000   2017  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000   2014  Diesel
#
#   seller_type transmission         owner  static_column_value
# 0  Individual       Manual   First Owner                    1
# 1  Individual       Manual   First Owner                    1
# 2  Individual       Manual   First Owner                    1
# 3  Individual       Manual   First Owner                    1
# 4  Individual       Manual  Second Owner                    1

# %%
df.drop('static_column_value',axis=1,inplace=True)#change the original dataframe by droping column
#no need for reassignment #inplace=true means permanent delete
df.head()
# Out:
#                        name  selling_price  year  km_driven  year2    fuel  \
# 0             Maruti 800 AC          60000  2007      70000   2007  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000   2007  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000   2012  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000   2017  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000   2014  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
#Combining two columns/concat columns
df['fuel_transmission']=df['fuel']+' '+df['transmission']# object + object column same datatype
df.head()
# Out:
#                        name  selling_price  year  km_driven  year2    fuel  \
# 0             Maruti 800 AC          60000  2007      70000   2007  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000   2007  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000   2012  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000   2017  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000   2014  Diesel
#
#   seller_type transmission         owner fuel_transmission
# 0  Individual       Manual   First Owner     Petrol Manual
# 1  Individual       Manual   First Owner     Petrol Manual
# 2  Individual       Manual   First Owner     Diesel Manual
# 3  Individual       Manual   First Owner     Petrol Manual
# 4  Individual       Manual  Second Owner     Diesel Manual

# %%
df['selling_price_owner']=df['selling_price'].astype(str)+' '+df['owner'] 
#concat two columns datatype should by same or use astype to change datatypoe
df.head()
# Out:
#                        name  selling_price  year  km_driven  year2    fuel  \
# 0             Maruti 800 AC          60000  2007      70000   2007  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000   2007  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000   2012  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000   2017  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000   2014  Diesel
#
#   seller_type transmission         owner fuel_transmission  \
# 0  Individual       Manual   First Owner     Petrol Manual
# 1  Individual       Manual   First Owner     Petrol Manual
# 2  Individual       Manual   First Owner     Diesel Manual
# 3  Individual       Manual   First Owner     Petrol Manual
# 4  Individual       Manual  Second Owner     Diesel Manual
#
#    selling_price_owner
# 0    60000 First Owner
# 1   135000 First Owner
# 2   600000 First Owner
# 3   250000 First Owner
# 4  450000 Second Owner

# %%
#Numerical operations

# %%
df['price_per_driven']=df['selling_price']/df['km_driven']
df.head()
# Out:
#                        name  selling_price  year  km_driven  year2    fuel  \
# 0             Maruti 800 AC          60000  2007      70000   2007  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000   2007  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000   2012  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000   2017  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000   2014  Diesel
#
#   seller_type transmission         owner fuel_transmission  \
# 0  Individual       Manual   First Owner     Petrol Manual
# 1  Individual       Manual   First Owner     Petrol Manual
# 2  Individual       Manual   First Owner     Diesel Manual
# 3  Individual       Manual   First Owner     Petrol Manual
# 4  Individual       Manual  Second Owner     Diesel Manual
#
#    selling_price_owner  price_per_driven
# 0    60000 First Owner          0.857143
# 1   135000 First Owner          2.700000
# ...

# %%
df['plus_km']=df['selling_price']+df['km_driven']
df.head()
# Out:
#                        name  selling_price  year  km_driven  year2    fuel  \
# 0             Maruti 800 AC          60000  2007      70000   2007  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000   2007  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000   2012  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000   2017  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000   2014  Diesel
#
#   seller_type transmission         owner fuel_transmission  \
# 0  Individual       Manual   First Owner     Petrol Manual
# 1  Individual       Manual   First Owner     Petrol Manual
# 2  Individual       Manual   First Owner     Diesel Manual
# 3  Individual       Manual   First Owner     Petrol Manual
# 4  Individual       Manual  Second Owner     Diesel Manual
#
#    selling_price_owner  price_per_driven  plus_km
# 0    60000 First Owner          0.857143   130000
# 1   135000 First Owner          2.700000   185000
# ...

# %%
##Applying function

# %%
df.name.unique()
# Out:
# array(['Maruti 800 AC', 'Maruti Wagon R LXI Minor',
#        'Hyundai Verna 1.6 SX', ..., 'Mahindra Verito 1.5 D6 BSIII',
#        'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV',
#        'Hyundai i20 Magna 1.4 CRDi'], dtype=object)

# %%
##Extracting only the brand names from car name columns
ex='Maruti 800 AC'
ex=ex.lower()#lowercase
ex=ex.split(' ')# split based on space
brandname=ex[0]
ex
# Out:
# ['maruti', '800', 'ac']

# %%
brandname
# Out:
# 'maruti'

# %%
def getbrandname(x):
    x=x.lower()
    x=x.split(' ')
    x=x[0]
    return x

# %%
getbrandname('Maruti 800 AC')
# Out:
# 'maruti'

# %%
df['brandname']=df['name'].apply(getbrandname)#applying function through out the column````

# %%
df.head()
# Out:
#                        name  selling_price  year  km_driven  year2    fuel  \
# 0             Maruti 800 AC          60000  2007      70000   2007  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000   2007  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000   2012  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000   2017  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000   2014  Diesel
#
#   seller_type transmission         owner fuel_transmission  \
# 0  Individual       Manual   First Owner     Petrol Manual
# 1  Individual       Manual   First Owner     Petrol Manual
# 2  Individual       Manual   First Owner     Diesel Manual
# 3  Individual       Manual   First Owner     Petrol Manual
# 4  Individual       Manual  Second Owner     Diesel Manual
#
#    selling_price_owner  price_per_driven  plus_km brandname
# 0    60000 First Owner          0.857143   130000    maruti
# ...

# %%
del df['year2']

# %%
df.head(2)
# Out:
#                        name  selling_price  year  km_driven    fuel  \
# 0             Maruti 800 AC          60000  2007      70000  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000  Petrol
#
#   seller_type transmission        owner fuel_transmission selling_price_owner  \
# 0  Individual       Manual  First Owner     Petrol Manual   60000 First Owner
# 1  Individual       Manual  First Owner     Petrol Manual  135000 First Owner
#
#    price_per_driven  plus_km brandname
# 0          0.857143   130000    maruti
# 1          2.700000   185000    maruti

# %%
df['age']=2023-df['year']

# %%
df.head()
# Out:
#                        name  selling_price  year  km_driven    fuel  \
# 0             Maruti 800 AC          60000  2007      70000  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000  Diesel
#
#   seller_type transmission         owner fuel_transmission  \
# 0  Individual       Manual   First Owner     Petrol Manual
# 1  Individual       Manual   First Owner     Petrol Manual
# 2  Individual       Manual   First Owner     Diesel Manual
# 3  Individual       Manual   First Owner     Petrol Manual
# 4  Individual       Manual  Second Owner     Diesel Manual
#
#    selling_price_owner  price_per_driven  plus_km brandname  age
# 0    60000 First Owner          0.857143   130000    maruti   16
# 1   135000 First Owner          2.700000   185000    maruti   16
# ...

# %%
df['age_group']=df['age'].apply(lambda x : 'more than 10 year' if x>=10 else 'less than equal to 10 year')

# %%
df.head()
# Out:
#                        name  selling_price  year  km_driven    fuel  \
# 0             Maruti 800 AC          60000  2007      70000  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000  Diesel
#
#   seller_type transmission         owner fuel_transmission  \
# 0  Individual       Manual   First Owner     Petrol Manual
# 1  Individual       Manual   First Owner     Petrol Manual
# 2  Individual       Manual   First Owner     Diesel Manual
# 3  Individual       Manual   First Owner     Petrol Manual
# 4  Individual       Manual  Second Owner     Diesel Manual
#
#    selling_price_owner  price_per_driven  plus_km brandname  age  \
# 0    60000 First Owner          0.857143   130000    maruti   16
# 1   135000 First Owner          2.700000   185000    maruti   16
# ...

# %%
## Aggregation

# %%
## Group by

# %%
## Finding the number of cars in each fuel type

# %%
grp=df.groupby('fuel')
grp.count()
# Out:
#           name  selling_price  year  km_driven  seller_type  transmission  \
# fuel
# CNG         40             40    40         40           40            40
# Diesel    2153           2153  2153       2153         2153          2153
# Electric     1              1     1          1            1             1
# LPG         23             23    23         23           23            23
# Petrol    2123           2123  2123       2123         2123          2123
#
#           owner  fuel_transmission  selling_price_owner  price_per_driven  \
# fuel
# CNG          40                 40                   40                40
# Diesel     2153               2153                 2153              2153
# Electric      1                  1                    1                 1
# LPG          23                 23                   23                23
# Petrol     2123               2123                 2123              2123
#
#           plus_km  brandname   age  age_group
# fuel
# ...

# %%
grp.name.count()
# Out:
# fuel
# CNG           40
# Diesel      2153
# Electric       1
# LPG           23
# Petrol      2123
# Name: name, dtype: int64

# %%
df.groupby('fuel').agg({'name':'count'})
# Out:
#           name
# fuel
# CNG         40
# Diesel    2153
# Electric     1
# LPG         23
# Petrol    2123

# %%
#finding the average price for each seller type
df.groupby('seller_type').agg({'selling_price':'mean'})
# Out:
#                   selling_price
# seller_type
# Dealer            721822.890342
# Individual        424505.419236
# Trustmark Dealer  914950.980392

# %%
# find average,maximum, minimum and std price of car for each seller type
df.groupby('seller_type').agg({'selling_price':['mean','max','min','std']})
# Out:
#                   selling_price
#                            mean      max     min            std
# seller_type
# Dealer            721822.890342  8900000   22000  859955.854810
# Individual        424505.419236  4800000   20000  427283.949336
# Trustmark Dealer  914950.980392  2600000  295000  637361.320617

# %%
#find the avg,max,min & std for price of car and km driven in each seller type
df.groupby('seller_type').agg({'selling_price':['mean','max','min','std'],'km_driven':['mean','max','min','std']})
# Out:
#                   selling_price                                     km_driven  \
#                            mean      max     min            std          mean
# seller_type
# Dealer            721822.890342  8900000   22000  859955.854810  52827.259557
# Individual        424505.419236  4800000   20000  427283.949336  71167.556104
# Trustmark Dealer  914950.980392  2600000  295000  637361.320617  39202.215686
#
#
#                      max   min           std
# seller_type
# Dealer            806599   101  47552.761406
# Individual        400000     1  45869.087585
# Trustmark Dealer   79641  6480  19767.907010

# %%
# find the avg , max,min,and std for price of car in each seller type and age group
df.groupby(['seller_type','age_group']).agg({'selling_price':['mean','max','min','std']})
# Out:
#                                              selling_price                   \
#                                                       mean      max     min
# seller_type      age_group
# Dealer           less than equal to 10 year  872143.761983  8900000  110000
#                  more than 10 year           488033.359897  4200000   22000
# Individual       less than equal to 10 year  626598.373844  4800000   45000
#                  more than 10 year           247644.879769  2550000   20000
# Trustmark Dealer less than equal to 10 year  921089.108911  2600000  315000
#                  more than 10 year           295000.000000   295000  295000
#
#
#                                                       std
# seller_type      age_group
# Dealer           less than equal to 10 year  1.004008e+06
#                  more than 10 year           4.831273e+05
# Individual       less than equal to 10 year  5.100612e+05
#                  more than 10 year           2.184464e+05
# ...

# %%
# pivot table

# %%
pd.pivot_table(data=df,index='age_group',columns='seller_type',values='selling_price')# default aggregate function is mean
# Out:
# seller_type                        Dealer     Individual  Trustmark Dealer
# age_group
# less than equal to 10 year  872143.761983  626598.373844     921089.108911
# more than 10 year           488033.359897  247644.879769     295000.000000

# %%
pd.pivot_table(data=df,index='age_group',columns='seller_type',values='selling_price',aggfunc='count')
# Out:
# seller_type                 Dealer  Individual  Trustmark Dealer
# age_group
# less than equal to 10 year     605        1514               101
# more than 10 year              389        1730                 1

# %%
pd.pivot_table(data=df,index='age_group',columns='seller_type',values='selling_price',aggfunc='max')
# Out:
# seller_type                  Dealer  Individual  Trustmark Dealer
# age_group
# less than equal to 10 year  8900000     4800000           2600000
# more than 10 year           4200000     2550000            295000

# %%
## filtering of dataframe

# %%
df.head()
# Out:
#                        name  selling_price  year  km_driven    fuel  \
# 0             Maruti 800 AC          60000  2007      70000  Petrol
# 1  Maruti Wagon R LXI Minor         135000  2007      50000  Petrol
# 2      Hyundai Verna 1.6 SX         600000  2012     100000  Diesel
# 3    Datsun RediGO T Option         250000  2017      46000  Petrol
# 4     Honda Amaze VX i-DTEC         450000  2014     141000  Diesel
#
#   seller_type transmission         owner fuel_transmission  \
# 0  Individual       Manual   First Owner     Petrol Manual
# 1  Individual       Manual   First Owner     Petrol Manual
# 2  Individual       Manual   First Owner     Diesel Manual
# 3  Individual       Manual   First Owner     Petrol Manual
# 4  Individual       Manual  Second Owner     Diesel Manual
#
#    selling_price_owner  price_per_driven  plus_km brandname  age  \
# 0    60000 First Owner          0.857143   130000    maruti   16
# 1   135000 First Owner          2.700000   185000    maruti   16
# ...

# %%
# finding all the rows with year of 2014
df[df.year==2014]
# Out:
#                                      name  selling_price  year  km_driven  \
# 4                   Honda Amaze VX i-DTEC         450000  2014     141000
# 7                Tata Indigo Grand Petrol         240000  2014      60000
# 11               Tata Indigo Grand Petrol         250000  2014     100000
# 17                  Honda Amaze VX i-DTEC         450000  2014     141000
# 20               Tata Indigo Grand Petrol         240000  2014      60000
# ...                                   ...            ...   ...        ...
# 4275               Mahindra XUV500 W8 2WD         650000  2014     218000
# 4316              Nissan Terrano XL 85 PS         500000  2014      82000
# 4323                        Maruti 800 AC         195000  2014      75000
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)         409999  2014      80000
# 4336           Hyundai i20 Magna 1.4 CRDi         409999  2014      80000
#
#         fuel seller_type transmission         owner fuel_transmission  \
# ...

# %%
#finding all cars with price more than 1000000
df[df['selling_price']>1000000]
# Out:
#                                       name  selling_price  year  km_driven  \
# 12         Toyota Corolla Altis 1.8 VL CVT        1650000  2018      25000
# 25         Toyota Corolla Altis 1.8 VL CVT        1650000  2018      25000
# 27             Hyundai Venue SX Opt Diesel        1195000  2019       5000
# 29              Jaguar XF 2.2 Litre Luxury        1964999  2014      28000
# 30    Mercedes-Benz New C-Class 220 CDI AT        1425000  2013      59000
# ...                                    ...            ...   ...        ...
# 4274          Hyundai Verna CRDi 1.6 AT EX        1100000  2018      25000
# 4302                    BMW 7 Series 730Ld        1050000  2006      30000
# 4304    Audi Q5 3.0 TDI Quattro Technology        3899000  2018      22000
# 4311               Toyota Camry Hybrid 2.5        1900000  2017      20118
# 4313    Ford Endeavour 2.2 Titanium AT 4X2        2800000  2019      10000
#
# ...

# %%
#finding all cars of brandname toyota
df[df['brandname']=='toyota']
# Out:
#                                               name  selling_price  year  \
# 12                 Toyota Corolla Altis 1.8 VL CVT        1650000  2018
# 25                 Toyota Corolla Altis 1.8 VL CVT        1650000  2018
# 38                       Toyota Corolla Altis G AT         900000  2016
# 39           Toyota Innova 2.5 G (Diesel) 7 Seater        1300000  2015
# 66                                 Toyota Etios GD         525000  2014
# ...                                            ...            ...   ...
# 4216        Toyota Innova 2.5 VX (Diesel) 8 Seater        1050000  2014
# 4224                    Toyota Fortuner 2.7 2WD AT        2500000  2016
# 4231   Toyota Innova 2.5 G (Diesel) 8 Seater BS IV         800000  2011
# 4311                       Toyota Camry Hybrid 2.5        1900000  2017
# 4334  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV         600000  2012
#
#       km_driven    fuel seller_type transmission         owner  \
# ...

# %%
# finding all cars with brand audi and BMW
df[(df['brandname']=='bmw') | (df['brandname']=='audi')]
# Out:
#                                       name  selling_price  year  km_driven  \
# 32                         Audi Q5 2.0 TDI        1190000  2011     175900
# 35         Audi A6 2.0 TDI  Design Edition        1735000  2013      50000
# 43            BMW 3 Series 320d Sport Line        1550000  2013      75800
# 44          Audi Q7 35 TDI Quattro Premium        1250000  2009      78000
# 94            Audi A6 2.0 TDI Premium Plus        1470000  2014      34000
# ...                                    ...            ...   ...        ...
# 3873    Audi Q5 3.0 TDI Quattro Technology        3200000  2015      30000
# 3883         BMW 5 Series 520d Luxury Line        4800000  2019      12999
# 4163  Audi Q3 2.0 TDI Quattro Premium Plus        1400000  2012     118000
# 4302                    BMW 7 Series 730Ld        1050000  2006      30000
# 4304    Audi Q5 3.0 TDI Quattro Technology        3899000  2018      22000
#
# ...

# %%
# filtering based on multiple names
df[df['brandname'].isin(['audi','bmw','isuzu'])]
# Out:
#                                       name  selling_price  year  km_driven  \
# 32                         Audi Q5 2.0 TDI        1190000  2011     175900
# 35         Audi A6 2.0 TDI  Design Edition        1735000  2013      50000
# 43            BMW 3 Series 320d Sport Line        1550000  2013      75800
# 44          Audi Q7 35 TDI Quattro Premium        1250000  2009      78000
# 94            Audi A6 2.0 TDI Premium Plus        1470000  2014      34000
# ...                                    ...            ...   ...        ...
# 3873    Audi Q5 3.0 TDI Quattro Technology        3200000  2015      30000
# 3883         BMW 5 Series 520d Luxury Line        4800000  2019      12999
# 4163  Audi Q3 2.0 TDI Quattro Premium Plus        1400000  2012     118000
# 4302                    BMW 7 Series 730Ld        1050000  2006      30000
# 4304    Audi Q5 3.0 TDI Quattro Technology        3899000  2018      22000
#
# ...

# %%
# filtering based on name column
df[df['name'].str.contains('BMW')]
# Out:
#                                name  selling_price  year  km_driven    fuel  \
# 43     BMW 3 Series 320d Sport Line        1550000  2013      75800  Diesel
# 102         BMW X1 sDrive 20d xLine        2750000  2017      13000  Diesel
# 105              BMW 7 Series 730Ld        2500000  2012      48000  Diesel
# 204   BMW 5 Series 520d Luxury Line        2900000  2017      40000  Diesel
# 318         BMW 3 Series 320d Sport        2000000  2013     167223  Diesel
# 320     BMW X1 sDrive 20d Exclusive        1375000  2011      60000  Diesel
# 551   BMW 3 Series 320d Luxury Line        2150000  2016      43000  Diesel
# 555         BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 574         BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 593         BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 612         BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# ...

# %%
#error
#df[df['name'].str.contains(['BMW','Audi'])]# list cannot be passed in str.contains

# %%
#filtering based on multiple conditions
#finding all BMW cars with selling price more than 15 lakh
df[(df['brandname']=='bmw') & (df['selling_price']> 1500000)]
# Out:
#                                name  selling_price  year  km_driven    fuel  \
# 43     BMW 3 Series 320d Sport Line        1550000  2013      75800  Diesel
# 102         BMW X1 sDrive 20d xLine        2750000  2017      13000  Diesel
# 105              BMW 7 Series 730Ld        2500000  2012      48000  Diesel
# 204   BMW 5 Series 520d Luxury Line        2900000  2017      40000  Diesel
# 318         BMW 3 Series 320d Sport        2000000  2013     167223  Diesel
# 551   BMW 3 Series 320d Luxury Line        2150000  2016      43000  Diesel
# 555         BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 574         BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 593         BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 612         BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 900         BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# ...

# %%
#multiple cars
df[df['brandname'].isin(['bmw','audi','toyota'])]
# Out:
#                                               name  selling_price  year  \
# 12                 Toyota Corolla Altis 1.8 VL CVT        1650000  2018
# 25                 Toyota Corolla Altis 1.8 VL CVT        1650000  2018
# 32                                 Audi Q5 2.0 TDI        1190000  2011
# 35                 Audi A6 2.0 TDI  Design Edition        1735000  2013
# 38                       Toyota Corolla Altis G AT         900000  2016
# ...                                            ...            ...   ...
# 4231   Toyota Innova 2.5 G (Diesel) 8 Seater BS IV         800000  2011
# 4302                            BMW 7 Series 730Ld        1050000  2006
# 4304            Audi Q5 3.0 TDI Quattro Technology        3899000  2018
# 4311                       Toyota Camry Hybrid 2.5        1900000  2017
# 4334  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV         600000  2012
#
#       km_driven    fuel seller_type transmission        owner  \
# ...

# %%
# finding all bmw cars with selling price more than 15 lakh and first owner
df[(df['brandname']=='bmw') & (df['selling_price']>1500000) & (df['owner']=='First Owner')].head()
# Out:
#                               name  selling_price  year  km_driven    fuel  \
# 102        BMW X1 sDrive 20d xLine        2750000  2017      13000  Diesel
# 105             BMW 7 Series 730Ld        2500000  2012      48000  Diesel
# 204  BMW 5 Series 520d Luxury Line        2900000  2017      40000  Diesel
# 318        BMW 3 Series 320d Sport        2000000  2013     167223  Diesel
# 551  BMW 3 Series 320d Luxury Line        2150000  2016      43000  Diesel
#
#     seller_type transmission        owner fuel_transmission  \
# 102  Individual    Automatic  First Owner  Diesel Automatic
# 105      Dealer    Automatic  First Owner  Diesel Automatic
# 204  Individual    Automatic  First Owner  Diesel Automatic
# 318      Dealer    Automatic  First Owner  Diesel Automatic
# 551      Dealer    Automatic  First Owner  Diesel Automatic
#
#      selling_price_owner  price_per_driven  plus_km brandname  age  \
# 102  2750000 First Owner        211.538462  2763000       bmw    6
# ...

# %%
# finding all cars either bmw or audi with year more than 2018 and first owner
df[((df['brandname']=='bmw') | (df['brandname']=='audi')) & (df['year']>2018) & (df['owner']=='First Owner')].head()
# Out:
#                         name  selling_price  year  km_driven    fuel  \
# 555  BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 574  BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 593  BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 612  BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
# 900  BMW X5 xDrive 30d xLine        4950000  2019      30000  Diesel
#
#     seller_type transmission        owner fuel_transmission  \
# 555      Dealer    Automatic  First Owner  Diesel Automatic
# 574      Dealer    Automatic  First Owner  Diesel Automatic
# 593      Dealer    Automatic  First Owner  Diesel Automatic
# 612      Dealer    Automatic  First Owner  Diesel Automatic
# 900      Dealer    Automatic  First Owner  Diesel Automatic
#
#      selling_price_owner  price_per_driven  plus_km brandname  age  \
# 555  4950000 First Owner             165.0  4980000       bmw    4
# ...

# %%
#
df[((df['brandname']=='bmw') | (df['selling_price']> 1500000)) & (df['year']>2018) & (df['owner']=='First Owner')].count()
# Out:
# name                   26
# selling_price          26
# year                   26
# km_driven              26
# fuel                   26
# seller_type            26
# transmission           26
# owner                  26
# fuel_transmission      26
# selling_price_owner    26
# price_per_driven       26
# plus_km                26
# brandname              26
# age                    26
# age_group              26
# dtype: int64
