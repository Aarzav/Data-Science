# %%
import numpy as np
import pandas as pd

# %%
combined_ages=pd.DataFrame([(22,24,20),(40,50,45)],columns=['class 1','class 2','class 3'])
combined_ages
# Out:
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
combined_ages.append({'class 1':35,'class 2':33,'class 3':21},ignore_index=True)
combined_ages
# Out:
# C:\Users\aarza\AppData\Local\Temp\ipykernel_20864\393380537.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_ages.append({'class 1':35,'class 2':33,'class 3':21},ignore_index=True)
#    class 1  class 2  class 3
# 0       22       24       20
# 1       40       50       45

# %%
#del combined_ages['class 3']
#combined_ages

# %%
#combined_ages.pop('class 2')

# %%
#combined_ages.drop(['class 1'],axis=1,inplace=True)
#combined_ages

# %%
combined_ages[~(combined_ages.values<50)]
# Out:
#    class 1  class 2  class 3
# 1       40       50       45

# %%
combined_ages.drop(1)
# Out:
#    class 1  class 2  class 3
# 0       22       24       20

# %%
periodic_table=pd.DataFrame({'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron']},index=['H','He','Li','Be','B'])
periodic_table
# Out:
#       Element
# H    Hydrogen
# He     Helium
# Li    Lithium
# Be  Beryllium
# B       Boron

# %%
periodic_table=pd.DataFrame({'Element':['Hydrogen','Helium','Lithium','Beryllium','Boron'],'Symbols':['H','He','Li','Be','B']})
periodic_table.set_index(['Symbols'])
# Out:
#            Element
# Symbols
# H         Hydrogen
# He          Helium
# Li         Lithium
# Be       Beryllium
# B            Boron

# %%
data=pd.read_csv(r'C:\Users\aarza\Desktop\Files\Gayathri files\Data-files-master\subset-covid-data.csv',index_col='date')
data.head()
# Out:
#                 country continent  day  month  year  cases  deaths  \
# date
# 2020-04-12  Afghanistan      Asia   12      4  2020     34       3
# 2020-04-12      Albania    Europe   12      4  2020     17       0
# 2020-04-12      Algeria    Africa   12      4  2020     64      19
# 2020-04-12      Andorra    Europe   12      4  2020     21       2
# 2020-04-12       Angola    Africa   12      4  2020      0       0
#
#            country_code  population
# date
# 2020-04-12          AFG  37172386.0
# 2020-04-12          ALB   2866376.0
# 2020-04-12          DZA  42228429.0
# 2020-04-12          AND     77006.0
# 2020-04-12          AGO  30809762.0

# %%
data.dtypes
# Out:
# country          object
# continent        object
# day               int64
# month             int64
# year              int64
# cases             int64
# deaths            int64
# country_code     object
# population      float64
# dtype: object

# %%
#df['date']=pd.todatetime(df['date'])

# %%
data.iloc[0:5]
# Out:
#                 country continent  day  month  year  cases  deaths  \
# date
# 2020-04-12  Afghanistan      Asia   12      4  2020     34       3
# 2020-04-12      Albania    Europe   12      4  2020     17       0
# 2020-04-12      Algeria    Africa   12      4  2020     64      19
# 2020-04-12      Andorra    Europe   12      4  2020     21       2
# 2020-04-12       Angola    Africa   12      4  2020      0       0
#
#            country_code  population
# date
# 2020-04-12          AFG  37172386.0
# 2020-04-12          ALB   2866376.0
# 2020-04-12          DZA  42228429.0
# 2020-04-12          AND     77006.0
# 2020-04-12          AGO  30809762.0

# %%
data.iloc[:,:3]
# Out:
#                 country continent  day
# date
# 2020-04-12  Afghanistan      Asia   12
# 2020-04-12      Albania    Europe   12
# 2020-04-12      Algeria    Africa   12
# 2020-04-12      Andorra    Europe   12
# 2020-04-12       Angola    Africa   12
# ...                 ...       ...  ...
# 2020-04-12    Venezuela   America   12
# 2020-04-12      Vietnam      Asia   12
# 2020-04-12        Yemen      Asia   12
# 2020-04-12       Zambia    Africa   12
# 2020-04-12     Zimbabwe    Africa   12
#
# [206 rows x 3 columns]

# %%
data.iloc[99]
# Out:
# country           Jamaica
# continent         America
# day                    12
# month                   4
# year                 2020
# cases                   4
# deaths                  0
# country_code          JAM
# population      2934855.0
# Name: 2020-04-12, dtype: object

# %%
data.loc['2020-04-12']
# Out:
#                 country continent  day  month  year  cases  deaths  \
# date
# 2020-04-12  Afghanistan      Asia   12      4  2020     34       3
# 2020-04-12      Albania    Europe   12      4  2020     17       0
# 2020-04-12      Algeria    Africa   12      4  2020     64      19
# 2020-04-12      Andorra    Europe   12      4  2020     21       2
# 2020-04-12       Angola    Africa   12      4  2020      0       0
# ...                 ...       ...  ...    ...   ...    ...     ...
# 2020-04-12    Venezuela   America   12      4  2020      0       0
# 2020-04-12      Vietnam      Asia   12      4  2020      4       0
# 2020-04-12        Yemen      Asia   12      4  2020      0       0
# 2020-04-12       Zambia    Africa   12      4  2020      0       0
# 2020-04-12     Zimbabwe    Africa   12      4  2020      3       0
#
#            country_code  population
# date
# 2020-04-12          AFG  37172386.0
# 2020-04-12          ALB   2866376.0
# 2020-04-12          DZA  42228429.0
# ...

# %%
data.loc[:,'cases']
# Out:
# date
# 2020-04-12    34
# 2020-04-12    17
# 2020-04-12    64
# 2020-04-12    21
# 2020-04-12     0
#               ..
# 2020-04-12     0
# 2020-04-12     4
# 2020-04-12     0
# 2020-04-12     0
# 2020-04-12     3
# Name: cases, Length: 206, dtype: int64

# %%
data.iloc[:5,-1:-4:-1]
# Out:
#             population country_code  deaths
# date
# 2020-04-12  37172386.0          AFG       3
# 2020-04-12   2866376.0          ALB       0
# 2020-04-12  42228429.0          DZA      19
# 2020-04-12     77006.0          AND       2
# 2020-04-12  30809762.0          AGO       0

# %%
data.iloc[:5,-3:]
# Out:
#             deaths country_code  population
# date
# 2020-04-12       3          AFG  37172386.0
# 2020-04-12       0          ALB   2866376.0
# 2020-04-12      19          DZA  42228429.0
# 2020-04-12       2          AND     77006.0
# 2020-04-12       0          AGO  30809762.0

# %%
data.iloc[[1,5],[0,3]]
# Out:
#              country  month
# date
# 2020-04-12   Albania      4
# 2020-04-12  Anguilla      4

# %%
data.iloc[0:3,]
# Out:
#                 country continent  day  month  year  cases  deaths  \
# date
# 2020-04-12  Afghanistan      Asia   12      4  2020     34       3
# 2020-04-12      Albania    Europe   12      4  2020     17       0
# 2020-04-12      Algeria    Africa   12      4  2020     64      19
#
#            country_code  population
# date
# 2020-04-12          AFG  37172386.0
# 2020-04-12          ALB   2866376.0
# 2020-04-12          DZA  42228429.0

# %%
data=pd.read_csv(r'C:\Users\aarza\Desktop\Files\Gayathri files\Data-files-master\subset-covid-data.csv')
data.head()
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3      Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4       Angola    Africa  2020-04-12   12      4  2020      0       0
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0
# 3          AND     77006.0
# 4          AGO  30809762.0

# %%
data.query("(continent=='Asia')" "and (cases>=500)")
# Out:
#     country continent        date  day  month  year  cases  deaths  \
# 91    India      Asia  2020-04-12   12      4  2020    909      34
# 93     Iran      Asia  2020-04-12   12      4  2020   1837     125
# 100   Japan      Asia  2020-04-12   12      4  2020   1401      10
# 190  Turkey      Asia  2020-04-12   12      4  2020   5138      95
#
#     country_code    population
# 91           IND  1.352617e+09
# 93           IRN  8.180027e+07
# 100          JPN  1.265291e+08
# 190          TUR  8.231972e+07

# %%
data[(data['continent']=='Asia') & (data['country'].str.startswith('C'))]
# Out:
#      country continent        date  day  month  year  cases  deaths  \
# 33  Cambodia      Asia  2020-04-12   12      4  2020      2       0
# 42     China      Asia  2020-04-12   12      4  2020     93       0
#
#    country_code    population
# 33          KHM  1.624980e+07
# 42          CHN  1.392730e+09

# %%
df=data.groupby('continent')

# %%
df.groups.keys()
# Out:
# dict_keys(['Africa', 'America', 'Asia', 'Europe', 'Oceania', 'Other'])

# %%
data.groupby('continent')['cases','deaths'].sum()
# Out:
# C:\Users\aarza\AppData\Local\Temp\ipykernel_20864\1082880753.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('continent')['cases','deaths'].sum()
#            cases  deaths
# continent
# Africa       714      52
# America    33519    2111
# Asia       12979     383
# Europe     34141    3571
# Oceania       68       4
# Other          0       0

# %%
df.get_group('Europe')
# Out:
#                     country continent        date  day  month  year  cases  \
# 1                   Albania    Europe  2020-04-12   12      4  2020     17
# 3                   Andorra    Europe  2020-04-12   12      4  2020     21
# 8                   Armenia    Europe  2020-04-12   12      4  2020     30
# 11                  Austria    Europe  2020-04-12   12      4  2020    247
# 12               Azerbaijan    Europe  2020-04-12   12      4  2020     67
# 17                  Belarus    Europe  2020-04-12   12      4  2020    245
# 18                  Belgium    Europe  2020-04-12   12      4  2020   1351
# 25   Bosnia_and_Herzegovina    Europe  2020-04-12   12      4  2020     47
# 30                 Bulgaria    Europe  2020-04-12   12      4  2020     26
# 47                  Croatia    Europe  2020-04-12   12      4  2020     39
# 50                   Cyprus    Europe  2020-04-12   12      4  2020     21
# ...

# %%
df.filter(lambda x:x['deaths'].mean()>=40)
# Out:
#                           country continent        date  day  month  year  \
# 1                         Albania    Europe  2020-04-12   12      4  2020
# 3                         Andorra    Europe  2020-04-12   12      4  2020
# 5                        Anguilla   America  2020-04-12   12      4  2020
# 6             Antigua_and_Barbuda   America  2020-04-12   12      4  2020
# 7                       Argentina   America  2020-04-12   12      4  2020
# ..                            ...       ...         ...  ...    ...   ...
# 195                United_Kingdom    Europe  2020-04-12   12      4  2020
# 197  United_States_Virgin_Islands   America  2020-04-12   12      4  2020
# 198      United_States_of_America   America  2020-04-12   12      4  2020
# 199                       Uruguay   America  2020-04-12   12      4  2020
# 201                     Venezuela   America  2020-04-12   12      4  2020
#
#      cases  deaths country_code   population
# ...

# %%
df['population'].transform(lambda x:x/1000000)
# Out:
# 0      37.172386
# 1       2.866376
# 2      42.228429
# 3       0.077006
# 4      30.809762
#          ...
# 201    28.870195
# 202    95.540395
# 203    28.498687
# 204    17.351822
# 205    14.439018
# Name: population, Length: 206, dtype: float64

# %%
data
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
data.isnull().sum()
# Out:
# country         0
# continent       0
# date            0
# day             0
# month           0
# year            0
# cases           0
# deaths          0
# country_code    4
# population      4
# dtype: int64

# %%
data.fillna(0)
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
df.apply(lambda x:x.isna().sum())
# Out:
#            country  continent  date  day  month  year  cases  deaths  \
# continent
# Africa           0          0     0    0      0     0      0       0
# America          0          0     0    0      0     0      0       0
# Asia             0          0     0    0      0     0      0       0
# Europe           0          0     0    0      0     0      0       0
# Oceania          0          0     0    0      0     0      0       0
# Other            0          0     0    0      0     0      0       0
#
#            country_code  population
# continent
# Africa                0           1
# America               3           3
# Asia                  0           0
# Europe                0           0
# Oceania               0           0
# Other                 1           0
